# %%
import gensim
import pandas as pd
from gensim import corpora
from gensim import similarities
from pprint import pprint

# %%
def calSimilarity(app: str, row: int)->pd.DataFrame:
    reviews_df = pd.read_csv(f'crawler_result/{app}.csv')
    reviews = reviews_df['review']
    # list of app reviews
    reviews = reviews.to_list()
    # lemmetation
    texts = [[word for word in review.lower().split()] for review in reviews]
    # create dict
    dictionary = corpora.Dictionary(texts)
    # bag-of-words
    corpus = [dictionary.doc2bow(text) for text in texts]
    # LDA modeling
    lda_model = gensim.models.LdaModel(corpus, num_topics=2, id2word=dictionary, passes=15)
    # topics
    # pprint(lda_model.print_topics())
    kw_df = pd.read_csv('kw_db.csv')
    feature_df = kw_df['functions'][row]
    # list of features
    features = feature_df.split('\n')
    # use gensim similarities module
    index = similarities.MatrixSimilarity(lda_model[corpus])
    # 創建一個空的列表來存儲所有的結果
    results = []
    # compare the similarity
    for feature in features:
        feature_bow = dictionary.doc2bow(feature.lower().split())
        feature_lda = lda_model[feature_bow]
        sims = index[feature_lda]
        for review, score in zip(reviews, sims):
            # 將每次迭代的結果添加到results列表中
            results.append({'feature': feature, 'review': review, 'similarity score': score})
    # 使用results列表來創建一個DataFrame
    df = pd.DataFrame(results)
    df.to_csv(f'feature_sim_score_{app}.csv')
    return df

# %%
kw_df = pd.read_csv('kw_db.csv')
kw_df
# Out:
#                       Unnamed: 0  \
# 0       Duoswim:swim workout app
# 1          swim.com:swim tracker
# 2       swimup-swimming training
# 3                      form swim
# 4  myswimpro:#1 swim workout app
# 5                 garmin connect
# 6                        fitness
#
#                                            functions
# 0  personal AI coach\nguided workouts\n1000+ swim...
# 1  track your swims and achieve your goals\ndisco...
# 2  personalized training plans\ndrill&technique v...
# 3  choose own plans or workouts in app,can also l...
# 4  MySwimPro Coach unlocks:\nPersonalized swim Tr...
# 5                   記錄距離\n設定泳池大小\n泳姿辨識\n自動休息\n技術訓練日誌
# 6  automatically tracks your splits and auto sets...

# %%
df = calSimilarity('duoswim', 0)
df
# Out:
#                           feature  \
# 0               personal AI coach
# 1               personal AI coach
# 2               personal AI coach
# 3               personal AI coach
# 4               personal AI coach
# ..                            ...
# 115  training statistics overview
# 116  training statistics overview
# 117  training statistics overview
# 118  training statistics overview
# 119  training statistics overview
#
#                                                 review  similarity score
# 0    Fantastic app, it changed my way to workout in...          0.942395
# 1    Finally a swim app that looks great and provid...          0.942395
# 2    Positive: The coaching side seems ok and decen...          0.942395
# 3    This app is very easy to use. I love how you c...          0.334502
# 4    Perfect app. Used to love swimming but hadn’t ...          0.948113
# ..                                                 ...               ...
# 115  This app is quality, helping me build up my sw...          0.351541
# 116  I am so impressed with the variety of programs...          0.348506
# 117  I am an experienced swimmer and this app has s...          0.359175
# 118  Perfect app for me to start my training journe...          0.954189
# 119  Awesome app, great training schemes and graphi...          0.535427
#
# [120 rows x 3 columns]

# %%
df = calSimilarity('swimcom', 1)
df
# Out:
#                                       feature  \
# 0     track your swims and achieve your goals
# 1     track your swims and achieve your goals
# 2     track your swims and achieve your goals
# 3     track your swims and achieve your goals
# 4     track your swims and achieve your goals
# ...                                       ...
# 1381                view performace over time
# 1382                view performace over time
# 1383                view performace over time
# 1384                view performace over time
# 1385                view performace over time
#
#                                                  review  similarity score
# 0     After using this app for two years on a Pebble...          0.992552
# 1     Strictly from an App Design standpoint, it bre...          0.991204
# 2     They’ve made some good improvements to the app...          0.132343
# 3     At 70 yo I sometimes ( no, all the time) need ...          0.991204
# 4     This app has all the potential of being great ...          0.991204
# ...                                                 ...               ...
# 1381  I have used this app with my old Apple Watch S...          0.206706
# 1382  I want to use this app. I love swim.com and us...          0.984305
# 1383  ***Update - 02-10-2017\nMore updates have been...          0.980505
# 1384  App.has gone from functional to brick. Says it...          0.988444
# 1385  It's January now and I haven't been able to sy...          0.196492
#
# [1386 rows x 3 columns]

# %%
df = calSimilarity('swimup', 2)
df
# Out:
#                              feature  \
# 0        personalized training plans
# 1        personalized training plans
# 2        personalized training plans
# 3        personalized training plans
# 4        personalized training plans
# 5        personalized training plans
# 6        personalized training plans
# 7        personalized training plans
# 8      drill&technique video library
# 9      drill&technique video library
# 10     drill&technique video library
# 11     drill&technique video library
# 12     drill&technique video library
# 13     drill&technique video library
# 14     drill&technique video library
# 15     drill&technique video library
# 16          easy-to -follow workouts
# 17          easy-to -follow workouts
# 18          easy-to -follow workouts
# 19          easy-to -follow workouts
# 20          easy-to -follow workouts
# 21          easy-to -follow workouts
# 22          easy-to -follow workouts
# 23          easy-to -follow workouts
# 24  analytics to track your progress
# 25  analytics to track your progress
# 26  analytics to track your progress
# 27  analytics to track your progress
# 28  analytics to track your progress
# 29  analytics to track your progress
# 30  analytics to track your progress
# 31  analytics to track your progress
#
#                                                review  similarity score
# 0   Amazing app, amazing coach and superb courses....          0.455866
# 1   Tried a few training apps for getting into swi...          0.901291
# 2   I have been trying to learn how to freestyle w...          0.890048
# 3   Great app! Simple as it is, works good for beg...          0.900084
# 4   They put me on 2 levels before champion but th...          0.466743
# 5               Thank you guys. Appreciate your work.          0.535543
# 6   I love Swimup’s YouTube channel so I was reall...          0.455866
# 7      No voice tutorials makes these videos useless.          0.522945
# 8   Amazing app, amazing coach and superb courses....          0.940236
# 9   Tried a few training apps for getting into swi...          0.364191
# 10  I have been trying to learn how to freestyle w...          0.340524
# 11  Great app! Simple as it is, works good for beg...          0.361602
# 12  They put me on 2 levels before champion but th...          0.944339
# 13              Thank you guys. Appreciate your work.          0.967494
# 14  I love Swimup’s YouTube channel so I was reall...          0.940236
# 15     No voice tutorials makes these videos useless.          0.963633
# 16  Amazing app, amazing coach and superb courses....          0.944746
# 17  Tried a few training apps for getting into swi...          0.351587
# 18  I have been trying to learn how to freestyle w...          0.327802
# 19  Great app! Simple as it is, works good for beg...          0.348984
# 20  They put me on 2 levels before champion but th...          0.948694
# 21              Thank you guys. Appreciate your work.          0.970820
# 22  I love Swimup’s YouTube channel so I was reall...          0.944746
# 23     No voice tutorials makes these videos useless.          0.967152
# 24  Amazing app, amazing coach and superb courses....          0.296109
# 25  Tried a few training apps for getting into swi...          0.962336
# 26  I have been trying to learn how to freestyle w...          0.955154
# 27  Great app! Simple as it is, works good for beg...          0.961577
# 28  They put me on 2 levels before champion but th...          0.307796
# 29              Thank you guys. Appreciate your work.          0.382428
# 30  I love Swimup’s YouTube channel so I was reall...          0.296109
# 31     No voice tutorials makes these videos useless.          0.368666

# %%
df = calSimilarity('form', 3)
df
# Out:
#                                                feature  \
# 0    choose own plans or workouts in app,can also l...
# 1    choose own plans or workouts in app,can also l...
# 2    choose own plans or workouts in app,can also l...
# 3    choose own plans or workouts in app,can also l...
# 4    choose own plans or workouts in app,can also l...
# ..                                                 ...
# 300  customize your goggles(split times/stroke coun...
# 301  customize your goggles(split times/stroke coun...
# 302  customize your goggles(split times/stroke coun...
# 303  customize your goggles(split times/stroke coun...
# 304  customize your goggles(split times/stroke coun...
#
#                                                 review  similarity score
# 0    I like sport gadgets, but usually 9 out of 10 ...          0.998901
# 1    My biggest question was if I was going to be a...          0.998901
# 2    This has been a game changer in how I swim. Fi...          0.998901
# 3    The googles are fine and the workout generatio...          0.998901
# 4    This and bone conduction headphones have me sw...          0.998901
# ..                                                 ...               ...
# 300                              As described in title          0.835048
# 301  It recognizes freestyle but all my breast stro...          0.783641
# 302  I was excited when I first saw the Form goggle...          0.762863
# 303  Great goggles, but major sync issues to Apple ...          0.762863
# 304                          Great app, great goggles!          0.863208
#
# [305 rows x 3 columns]

# %%
df = calSimilarity('myswimpro', 4)
df
# Out:
#                        feature  \
# 0     MySwimPro Coach unlocks:
# 1     MySwimPro Coach unlocks:
# 2     MySwimPro Coach unlocks:
# 3     MySwimPro Coach unlocks:
# 4     MySwimPro Coach unlocks:
# ...                        ...
# 9067            Follow friends
# 9068            Follow friends
# 9069            Follow friends
# 9070            Follow friends
# 9071            Follow friends
#
#                                                  review  similarity score
# 0     Got the app 5 weeks ago and I have made more p...          0.945633
# 1     I am not a competíos swimmer but I enjoy it an...          0.869745
# 2     Very impressed.  As a long time swimmer with a...          0.945633
# 3     Let’s be honest, for many of us, our best comp...          0.461538
# 4     First and foremost SwimPro is a great app with...          0.945633
# ...                                                 ...               ...
# 9067  Do not get this app!  It will work for a while...          0.911675
# 9068  I've used this app 3 times and all 3 times I g...          0.222136
# 9069  I downloaded the app to see if I could use it ...          0.237856
# 9070  App is useless. Cant even log in using email. ...          0.339782
# 9071  The worst,it is ten dollars a month just to un...          0.236050
#
# [9072 rows x 3 columns]
