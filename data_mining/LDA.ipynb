# %%
import gensim
import pandas as pd
from gensim import corpora
from gensim import similarities
from pprint import pprint

# %%
def calSimilarity(app: str, row: int)->pd.DataFrame:
    name_list = ['high_ratings', 'low_ratings']
    sort_by_rating = get_sort_by_rating(app)
    for i in range(2):
        # reviews_df = pd.read_csv(f'crawler_result/{app}/{app}.csv')
        df = sort_by_rating[i]
        reviews = df['content']  # Update to use 'content' instead of 'review'
        # list of app reviews
        reviews = reviews.to_list()
        # lemmetation
        texts = [[word for word in str(review).lower().split()] for review in reviews if review is not None and not pd.isna(review)]
        # create dict
        dictionary = corpora.Dictionary(texts)
        # bag-of-words
        corpus = [dictionary.doc2bow(text) for text in texts]
        # LDA modeling
        lda_model = gensim.models.LdaModel(corpus, num_topics=2, id2word=dictionary, passes=15)
        # topics
        # pprint(lda_model.print_topics())
        kw_df = pd.read_csv('kw_db.csv')
        feature_df = kw_df['functions'][row]
        # list of features
        features = feature_df.split('\n')
        # use gensim similarities module
        index = similarities.MatrixSimilarity(lda_model[corpus])
        # 創建一個空的列表來存儲所有的結果
        results = []
        # compare the similarity
        for feature in features:
            feature_bow = dictionary.doc2bow(feature.lower().split())
            feature_lda = lda_model[feature_bow]
            sims = index[feature_lda]
            for review, score in zip(reviews, sims):
                # 將每次迭代的結果添加到results列表中
                results.append({'feature': feature, 'review': review, 'similarity score': score})
        # 使用results列表來創建一個DataFrame
        df = pd.DataFrame(results)
        df.to_csv(f'feature_sim_score_{app}_{name_list[i]}.csv')
    return df

def get_sort_by_rating(app: str)->[pd.DataFrame, pd.DataFrame]:
    # Splitting the combined dataset into two based on the score
    combined_data = pd.read_csv(f'result/{app}/{app}_combined.csv')
    # Good reviews with scores 4 and 5
    good_reviews = combined_data[combined_data['score'] >= 4]
    # Bad reviews with scores 1, 2, and 3
    bad_reviews = combined_data[combined_data['score'] <= 3]
    return [good_reviews, bad_reviews]

# %%
kw_df = pd.read_csv('kw_db.csv')
kw_df
# Out:
#                       Unnamed: 0  \
# 0       Duoswim:swim workout app
# 1          swim.com:swim tracker
# 2       swimup-swimming training
# 3                      form swim
# 4  myswimpro:#1 swim workout app
# 5                 garmin connect
# 6                        fitness
#
#                                            functions
# 0  personal AI coach\nguided workouts\n1000+ swim...
# 1  track your swims and achieve your goals\ndisco...
# 2  personalized training plans\ndrill&technique v...
# 3  choose own plans or workouts in app,can also l...
# 4  MySwimPro Coach unlocks:\nPersonalized swim Tr...
# 5                   記錄距離\n設定泳池大小\n泳姿辨識\n自動休息\n技術訓練日誌
# 6  automatically tracks your splits and auto sets...

# %%
kw_df['functions'][0]
# Out:
# 'personal AI coach\nguided workouts\n1000+ swim workouts\ntechnique video library\napple health\nnutrition\ntrack your swims\ntraining statistics overview'

# %%
df = calSimilarity('duoswim', 0)
df
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /home/morris/swim/data_mining/LDA.ipynb 儲存格 4 line 1
# ----> <a href='vscode-notebook-cell:/home/morris/swim/data_mining/LDA.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> df = calSimilarity('duoswim', 0)
#       <a href='vscode-notebook-cell:/home/morris/swim/data_mining/LDA.ipynb#W3sZmlsZQ%3D%3D?line=1'>2</a> df
#
# /home/morris/swim/data_mining/LDA.ipynb 儲存格 4 line 3
#      <a href='vscode-notebook-cell:/home/morris/swim/data_mining/LDA.ipynb#W3sZmlsZQ%3D%3D?line=29'>30</a> feature_bow = dictionary.doc2bow(feature.lower().split())
#      <a href='vscode-notebook-cell:/home/morris/swim/data_mining/LDA.ipynb#W3sZmlsZQ%3D%3D?line=30'>31</a> feature_lda = lda_model[feature_bow]
# ---> <a href='vscode-notebook-cell:/home/morris/swim/data_mining/LDA.ipynb#W3sZmlsZQ%3D%3D?line=31'>32</a> sims = index[feature_lda]
#      <a href='vscode-notebook-cell:/home/morris/swim/data_mining/LDA.ipynb#W3sZmlsZQ%3D%3D?line=32'>33</a> for review, score in zip(reviews, sims):
#      <a href='vscode-notebook-cell:/home/morris/swim/data_mining/LDA.ipynb#W3sZmlsZQ%3D%3D?line=33'>34</a>     # 將每次迭代的結果添加到results列表中
#      <a href='vscode-notebook-cell:/home/morris/swim/data_mining/LDA.ipynb#W3sZmlsZQ%3D%3D?line=34'>35</a>     results.append({'feature': feature, 'review': review, 'similarity score': score})
#
# File ~/swim/data_mining/.venv/lib/python3.11/site-packages/gensim/interfaces.py:337, in SimilarityABC.__getitem__(self, query)
#     335         else:
#     336             query = matutils.unitvec(query)
# --> 337 result = self.get_similarities(query)
#     339 if self.num_best is None:
#     340     return result
#
# File ~/swim/data_mining/.venv/lib/python3.11/site-packages/gensim/similarities/docsim.py:871, in MatrixSimilarity.get_similarities(self, query)
#     868         pass
#     869     else:
#     870         # default case: query is a single vector in sparse gensim format
# --> 871         query = matutils.sparse2full(query, self.num_features)
#     872     query = numpy.asarray(query, dtype=self.index.dtype)
#     874 # do a little transposition dance to stop numpy from making a copy of
#     875 # self.index internally in numpy.dot (very slow).
#
# File ~/swim/data_mining/.venv/lib/python3.11/site-packages/gensim/matutils.py:397, in sparse2full(doc, length)
#     395 doc = dict(doc)
#     396 # overwrite some of the zeroes with explicit values
# --> 397 result[list(doc)] = list(doc.values())
#     398 return result
#
# IndexError: index 1 is out of bounds for axis 0 with size 1

# %%
df = calSimilarity('swim-com', 1)
df
# Out:
#                                       feature  \
# 0     track your swims and achieve your goals
# 1     track your swims and achieve your goals
# 2     track your swims and achieve your goals
# 3     track your swims and achieve your goals
# 4     track your swims and achieve your goals
# ...                                       ...
# 2113                view performace over time
# 2114                view performace over time
# 2115                view performace over time
# 2116                view performace over time
# 2117                view performace over time
#
#                                                  review  similarity score
# 0     Strictly from an App Design standpoint, it bre...          0.862993
# 1     This app has all the potential of being great ...          0.862993
# 2     I want to like this app. It has potential, and...          0.862993
# 3     The new iPhone app format update is the worst ...          0.521507
# 4     This app is great when it works. Just after th...          0.505217
# ...                                                 ...               ...
# 2113  it worked consistently.  I bought the Pebble a...          0.940386
# 2114  The app will work, it would track my swim on e...          0.381513
# 2115  Polar m600 is an Android watch. However, this ...          0.375241
# 2116  On my pebble steel I get a message to check my...          0.949478
# 2117                                         Code brown          0.987989
#
# [2118 rows x 3 columns]

# %%
df = calSimilarity('swimup', 2)
df
# Out:
#                              feature  \
# 0        personalized training plans
# 1        personalized training plans
# 2        personalized training plans
# 3        personalized training plans
# 4        personalized training plans
# 5        personalized training plans
# 6        personalized training plans
# 7        personalized training plans
# 8        personalized training plans
# 9        personalized training plans
# 10       personalized training plans
# 11       personalized training plans
# 12       personalized training plans
# 13       personalized training plans
# 14       personalized training plans
# 15     drill&technique video library
# 16     drill&technique video library
# 17     drill&technique video library
# 18     drill&technique video library
# 19     drill&technique video library
# 20     drill&technique video library
# 21     drill&technique video library
# 22     drill&technique video library
# 23     drill&technique video library
# 24     drill&technique video library
# 25     drill&technique video library
# 26     drill&technique video library
# 27     drill&technique video library
# 28     drill&technique video library
# 29     drill&technique video library
# 30          easy-to -follow workouts
# 31          easy-to -follow workouts
# 32          easy-to -follow workouts
# 33          easy-to -follow workouts
# 34          easy-to -follow workouts
# 35          easy-to -follow workouts
# 36          easy-to -follow workouts
# 37          easy-to -follow workouts
# 38          easy-to -follow workouts
# 39          easy-to -follow workouts
# 40          easy-to -follow workouts
# 41          easy-to -follow workouts
# 42          easy-to -follow workouts
# 43          easy-to -follow workouts
# 44          easy-to -follow workouts
# 45  analytics to track your progress
# 46  analytics to track your progress
# 47  analytics to track your progress
# 48  analytics to track your progress
# 49  analytics to track your progress
# 50  analytics to track your progress
# 51  analytics to track your progress
# 52  analytics to track your progress
# 53  analytics to track your progress
# 54  analytics to track your progress
# 55  analytics to track your progress
# 56  analytics to track your progress
# 57  analytics to track your progress
# 58  analytics to track your progress
# 59  analytics to track your progress
#
#                                                review  similarity score
# 0   They put me on 2 levels before champion but th...          0.940652
# 1   I love Swimup’s YouTube channel so I was reall...          0.936594
# 2      No voice tutorials makes these videos useless.          0.417919
# 3   The app is decent, I am using it, but the beha...          0.936594
# 4   A lot of potential and probably the best of th...          0.350417
# 5   Subscription schemes to bleed customers dry ad...          0.940388
# 6             The videod keep loading without opening          0.436227
# 7   This app did not meet my expectation. I have u...          0.945363
# 8   I make a subscription and app stop working , c...          0.435867
# 9   Greate app but It is not available for samsung...          0.398985
# 10  I wish they explain that it's not free I can a...          0.949196
# 11                        Nothing is free in this app          0.966538
# 12                              This app is very poor          0.972871
# 13                                    Not recommended          0.992697
# 14                                           Paid app          0.993064
# 15  They put me on 2 levels before champion but th...          0.940627
# 16  I love Swimup’s YouTube channel so I was reall...          0.936569
# 17     No voice tutorials makes these videos useless.          0.417985
# 18  The app is decent, I am using it, but the beha...          0.936569
# 19  A lot of potential and probably the best of th...          0.350484
# 20  Subscription schemes to bleed customers dry ad...          0.940364
# 21            The videod keep loading without opening          0.436292
# 22  This app did not meet my expectation. I have u...          0.945340
# 23  I make a subscription and app stop working , c...          0.435932
# 24  Greate app but It is not available for samsung...          0.399052
# 25  I wish they explain that it's not free I can a...          0.949173
# 26                        Nothing is free in this app          0.966520
# 27                              This app is very poor          0.972854
# 28                                    Not recommended          0.992688
# 29                                           Paid app          0.993055
# 30  They put me on 2 levels before champion but th...          0.940654
# 31  I love Swimup’s YouTube channel so I was reall...          0.936596
# 32     No voice tutorials makes these videos useless.          0.417914
# 33  The app is decent, I am using it, but the beha...          0.936596
# 34  A lot of potential and probably the best of th...          0.350412
# 35  Subscription schemes to bleed customers dry ad...          0.940390
# 36            The videod keep loading without opening          0.436222
# 37  This app did not meet my expectation. I have u...          0.945365
# 38  I make a subscription and app stop working , c...          0.435863
# 39  Greate app but It is not available for samsung...          0.398981
# 40  I wish they explain that it's not free I can a...          0.949198
# 41                        Nothing is free in this app          0.966540
# 42                              This app is very poor          0.972872
# 43                                    Not recommended          0.992698
# 44                                           Paid app          0.993064
# 45  They put me on 2 levels before champion but th...          0.945811
# 46  I love Swimup’s YouTube channel so I was reall...          0.941925
# 47     No voice tutorials makes these videos useless.          0.403755
# 48  The app is decent, I am using it, but the beha...          0.941925
# 49  A lot of potential and probably the best of th...          0.335824
# 50  Subscription schemes to bleed customers dry ad...          0.945559
# 51            The videod keep loading without opening          0.422195
# 52  This app did not meet my expectation. I have u...          0.950314
# 53  I make a subscription and app stop working , c...          0.421832
# 54  Greate app but It is not available for samsung...          0.384692
# 55  I wish they explain that it's not free I can a...          0.953970
# 56                        Nothing is free in this app          0.970407
# 57                              This app is very poor          0.976348
# 58                                    Not recommended          0.994451
# 59                                           Paid app          0.994771

# %%
df = calSimilarity('form-swim', 3)
df
# Out:
#                                                feature  \
# 0    choose own plans or workouts in app,can also l...
# 1    choose own plans or workouts in app,can also l...
# 2    choose own plans or workouts in app,can also l...
# 3    choose own plans or workouts in app,can also l...
# 4    choose own plans or workouts in app,can also l...
# ..                                                 ...
# 215  customize your goggles(split times/stroke coun...
# 216  customize your goggles(split times/stroke coun...
# 217  customize your goggles(split times/stroke coun...
# 218  customize your goggles(split times/stroke coun...
# 219  customize your goggles(split times/stroke coun...
#
#                                                 review  similarity score
# 0    The googles are fine and the workout generatio...          0.998270
# 1    I like the FORM goggles and what they provide,...          0.998270
# 2    I was really disappointed to learn the collect...          0.998270
# 3    Goggles/software do function well and as adver...          0.998270
# 4    I have these googles and they are pretty neat....          0.998270
# ..                                                 ...               ...
# 215  Tried to download the app multiple times, but ...          0.283592
# 216  Cannot download. Took 2+ hours and 6 attempts ...          0.260046
# 217  I get many ptoblem when try to connect with de...          0.268003
# 218  Would be 5 star, only.problrm that's a pain fo...          0.915248
# 219  I want to look into buying but see that you do...          0.552817
#
# [220 rows x 3 columns]

# %%
df = calSimilarity('myswimpro', 4)
df
# Out:
#                        feature  \
# 0     MySwimPro Coach unlocks:
# 1     MySwimPro Coach unlocks:
# 2     MySwimPro Coach unlocks:
# 3     MySwimPro Coach unlocks:
# 4     MySwimPro Coach unlocks:
# ...                        ...
# 9985            Follow friends
# 9986            Follow friends
# 9987            Follow friends
# 9988            Follow friends
# 9989            Follow friends
#
#                                                  review  similarity score
# 0     This is the most complicated app for beginners...          0.977847
# 1     Save your money if you use a different watch.\...          0.242199
# 2     I loved the idea of this app and really wanted...          0.242199
# 3     I loved this app, but for the last week or mor...          0.242199
# 4     So this app is amazing when it works well, but...          0.242199
# ...                                                 ...               ...
# 9985                This is A good Log workout  Love it          0.833289
# 9986                                 Not useful at all.          0.906696
# 9987                                          Expensive          0.945184
# 9988                                         Refund me.          0.855220
# 9989                            Everything requires pro          0.865695
#
# [9990 rows x 3 columns]
