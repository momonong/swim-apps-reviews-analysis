# %%
import gensim
import pandas as pd
from gensim import corpora
from gensim import similarities
from pprint import pprint

# %%
def calSimilarity(app: str, row: int)->pd.DataFrame:
    name_list = ['high_ratings', 'low_ratings']
    sort_by_rating = get_sort_by_rating(app)
    for i in range(2):
        # reviews_df = pd.read_csv(f'crawler_result/{app}/{app}.csv')
        df = sort_by_rating[i]
        reviews = df['review']
        # list of app reviews
        reviews = reviews.to_list()
        # lemmetation
        texts = [[word for word in review.lower().split()] for review in reviews]
        # create dict
        dictionary = corpora.Dictionary(texts)
        # bag-of-words
        corpus = [dictionary.doc2bow(text) for text in texts]
        # LDA modeling
        lda_model = gensim.models.LdaModel(corpus, num_topics=2, id2word=dictionary, passes=15)
        # topics
        # pprint(lda_model.print_topics())
        kw_df = pd.read_csv('kw_db.csv')
        feature_df = kw_df['functions'][row]
        # list of features
        features = feature_df.split('\n')
        # use gensim similarities module
        index = similarities.MatrixSimilarity(lda_model[corpus])
        # 創建一個空的列表來存儲所有的結果
        results = []
        # compare the similarity
        for feature in features:
            feature_bow = dictionary.doc2bow(feature.lower().split())
            feature_lda = lda_model[feature_bow]
            sims = index[feature_lda]
            for review, score in zip(reviews, sims):
                # 將每次迭代的結果添加到results列表中
                results.append({'feature': feature, 'review': review, 'similarity score': score})
        # 使用results列表來創建一個DataFrame
        df = pd.DataFrame(results)
        df.to_csv(f'crawler_result/{app}/feature_sim_score_{app}_{name_list[i]}.csv')
    return df

def get_sort_by_rating(app: str)->[pd.DataFrame, pd.DataFrame]:
    high_ratings = pd.read_csv(f'crawler_result/{app}/{app}_high_ratings.csv')
    low_ratings = pd.read_csv(f'crawler_result/{app}/{app}_low_ratings.csv')
    return [high_ratings, low_ratings]

# %%
kw_df = pd.read_csv('kw_db.csv')
kw_df
# Out:
#                       Unnamed: 0  \
# 0       Duoswim:swim workout app
# 1          swim.com:swim tracker
# 2       swimup-swimming training
# 3                      form swim
# 4  myswimpro:#1 swim workout app
# 5                 garmin connect
# 6                        fitness
#
#                                            functions
# 0  personal AI coach\nguided workouts\n1000+ swim...
# 1  track your swims and achieve your goals\ndisco...
# 2  personalized training plans\ndrill&technique v...
# 3  choose own plans or workouts in app,can also l...
# 4  MySwimPro Coach unlocks:\nPersonalized swim Tr...
# 5                   記錄距離\n設定泳池大小\n泳姿辨識\n自動休息\n技術訓練日誌
# 6  automatically tracks your splits and auto sets...

# %%
df = calSimilarity('duoswim', 0)
df
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /home/morris/swim/data_mining/LDA.ipynb 儲存格 4 line 1
# ----> <a href='vscode-notebook-cell:/home/morris/swim/data_mining/LDA.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> df = calSimilarity('duoswim', 0)
#       <a href='vscode-notebook-cell:/home/morris/swim/data_mining/LDA.ipynb#W3sZmlsZQ%3D%3D?line=1'>2</a> df
#
# /home/morris/swim/data_mining/LDA.ipynb 儲存格 4 line 3
#      <a href='vscode-notebook-cell:/home/morris/swim/data_mining/LDA.ipynb#W3sZmlsZQ%3D%3D?line=29'>30</a> feature_bow = dictionary.doc2bow(feature.lower().split())
#      <a href='vscode-notebook-cell:/home/morris/swim/data_mining/LDA.ipynb#W3sZmlsZQ%3D%3D?line=30'>31</a> feature_lda = lda_model[feature_bow]
# ---> <a href='vscode-notebook-cell:/home/morris/swim/data_mining/LDA.ipynb#W3sZmlsZQ%3D%3D?line=31'>32</a> sims = index[feature_lda]
#      <a href='vscode-notebook-cell:/home/morris/swim/data_mining/LDA.ipynb#W3sZmlsZQ%3D%3D?line=32'>33</a> for review, score in zip(reviews, sims):
#      <a href='vscode-notebook-cell:/home/morris/swim/data_mining/LDA.ipynb#W3sZmlsZQ%3D%3D?line=33'>34</a>     # 將每次迭代的結果添加到results列表中
#      <a href='vscode-notebook-cell:/home/morris/swim/data_mining/LDA.ipynb#W3sZmlsZQ%3D%3D?line=34'>35</a>     results.append({'feature': feature, 'review': review, 'similarity score': score})
#
# File ~/swim/data_mining/.venv/lib/python3.11/site-packages/gensim/interfaces.py:337, in SimilarityABC.__getitem__(self, query)
#     335         else:
#     336             query = matutils.unitvec(query)
# --> 337 result = self.get_similarities(query)
#     339 if self.num_best is None:
#     340     return result
#
# File ~/swim/data_mining/.venv/lib/python3.11/site-packages/gensim/similarities/docsim.py:871, in MatrixSimilarity.get_similarities(self, query)
#     868         pass
#     869     else:
#     870         # default case: query is a single vector in sparse gensim format
# --> 871         query = matutils.sparse2full(query, self.num_features)
#     872     query = numpy.asarray(query, dtype=self.index.dtype)
#     874 # do a little transposition dance to stop numpy from making a copy of
#     875 # self.index internally in numpy.dot (very slow).
#
# File ~/swim/data_mining/.venv/lib/python3.11/site-packages/gensim/matutils.py:397, in sparse2full(doc, length)
#     395 doc = dict(doc)
#     396 # overwrite some of the zeroes with explicit values
# --> 397 result[list(doc)] = list(doc.values())
#     398 return result
#
# IndexError: index 1 is out of bounds for axis 0 with size 1

# %%
df = calSimilarity('swim-com', 1)
df
# Out:
#                                       feature  \
# 0     track your swims and achieve your goals
# 1     track your swims and achieve your goals
# 2     track your swims and achieve your goals
# 3     track your swims and achieve your goals
# 4     track your swims and achieve your goals
# ...                                       ...
# 1387                view performace over time
# 1388                view performace over time
# 1389                view performace over time
# 1390                view performace over time
# 1391                view performace over time
#
#                                                  review  similarity score
# 0     After using this app for two years on a Pebble...          0.993582
# 1     Strictly from an App Design standpoint, it bre...          0.993582
# 2     They’ve made some good improvements to the app...          0.113116
# 3     At 70 yo I sometimes ( no, all the time) need ...          0.993582
# 4     This app has all the potential of being great ...          0.113116
# ...                                                 ...               ...
# 1387  I have used this app with my old Apple Watch S...          0.190601
# 1388  I want to use this app. I love swim.com and us...          0.987577
# 1389  ***Update - 02-10-2017\nMore updates have been...          0.177296
# 1390  App.has gone from functional to brick. Says it...          0.991725
# 1391  It's January now and I haven't been able to sy...          0.984158
#
# [1392 rows x 3 columns]

# %%
df = calSimilarity('swimup', 2)
df
# Out:
#                              feature  \
# 0        personalized training plans
# 1        personalized training plans
# 2        personalized training plans
# 3        personalized training plans
# 4        personalized training plans
# 5        personalized training plans
# 6        personalized training plans
# 7        personalized training plans
# 8      drill&technique video library
# 9      drill&technique video library
# 10     drill&technique video library
# 11     drill&technique video library
# 12     drill&technique video library
# 13     drill&technique video library
# 14     drill&technique video library
# 15     drill&technique video library
# 16          easy-to -follow workouts
# 17          easy-to -follow workouts
# 18          easy-to -follow workouts
# 19          easy-to -follow workouts
# 20          easy-to -follow workouts
# 21          easy-to -follow workouts
# 22          easy-to -follow workouts
# 23          easy-to -follow workouts
# 24  analytics to track your progress
# 25  analytics to track your progress
# 26  analytics to track your progress
# 27  analytics to track your progress
# 28  analytics to track your progress
# 29  analytics to track your progress
# 30  analytics to track your progress
# 31  analytics to track your progress
#
#                                                review  similarity score
# 0   Amazing app, amazing coach and superb courses....          0.354730
# 1   Tried a few training apps for getting into swi...          0.953606
# 2   I have been trying to learn how to freestyle w...          0.354730
# 3   Great app! Simple as it is, works good for beg...          0.375119
# 4   They put me on 2 levels before champion but th...          0.365907
# 5               Thank you guys. Appreciate your work.          0.435076
# 6   I love Swimup’s YouTube channel so I was reall...          0.354730
# 7      No voice tutorials makes these videos useless.          0.958480
# 8   Amazing app, amazing coach and superb courses....          0.921860
# 9   Tried a few training apps for getting into swi...          0.439253
# 10  I have been trying to learn how to freestyle w...          0.921860
# 11  Great app! Simple as it is, works good for beg...          0.930125
# 12  They put me on 2 levels before champion but th...          0.926437
# 13              Thank you guys. Appreciate your work.          0.952198
# 14  I love Swimup’s YouTube channel so I was reall...          0.921860
# 15     No voice tutorials makes these videos useless.          0.454130
# 16  Amazing app, amazing coach and superb courses....          0.938371
# 17  Tried a few training apps for getting into swi...          0.398366
# 18  I have been trying to learn how to freestyle w...          0.938371
# 19  Great app! Simple as it is, works good for beg...          0.945714
# 20  They put me on 2 levels before champion but th...          0.942444
# 21              Thank you guys. Appreciate your work.          0.964984
# 22  I love Swimup’s YouTube channel so I was reall...          0.938371
# 23     No voice tutorials makes these videos useless.          0.413564
# 24  Amazing app, amazing coach and superb courses....          0.976409
# 25  Tried a few training apps for getting into swi...          0.271033
# 26  I have been trying to learn how to freestyle w...          0.976409
# 27  Great app! Simple as it is, works good for beg...          0.980904
# 28  They put me on 2 levels before champion but th...          0.978926
# 29              Thank you guys. Appreciate your work.          0.991543
# 30  I love Swimup’s YouTube channel so I was reall...          0.976409
# 31     No voice tutorials makes these videos useless.          0.287002

# %%
df = calSimilarity('form-swim', 3)
df
# Out:
#                                                feature  \
# 0    choose own plans or workouts in app,can also l...
# 1    choose own plans or workouts in app,can also l...
# 2    choose own plans or workouts in app,can also l...
# 3    choose own plans or workouts in app,can also l...
# 4    choose own plans or workouts in app,can also l...
# ..                                                 ...
# 305  customize your goggles(split times/stroke coun...
# 306  customize your goggles(split times/stroke coun...
# 307  customize your goggles(split times/stroke coun...
# 308  customize your goggles(split times/stroke coun...
# 309  customize your goggles(split times/stroke coun...
#
#                                                 review  similarity score
# 0    I like sport gadgets, but usually 9 out of 10 ...          0.981654
# 1    My biggest question was if I was going to be a...          0.981654
# 2    This has been a game changer in how I swim. Fi...          0.981654
# 3    The googles are fine and the workout generatio...          0.190673
# 4    This and bone conduction headphones have me sw...          0.981654
# ..                                                 ...               ...
# 305                              As described in title          0.995023
# 306  It recognizes freestyle but all my breast stro...          0.981801
# 307  Great goggles, but major sync issues to Apple ...          0.974699
# 308  I was excited when I first saw the Form goggle...          0.223523
# 309                          Great app, great goggles!          0.994979
#
# [310 rows x 3 columns]

# %%
df = calSimilarity('myswimpro', 4)
df
# Out:
#                        feature  \
# 0     MySwimPro Coach unlocks:
# 1     MySwimPro Coach unlocks:
# 2     MySwimPro Coach unlocks:
# 3     MySwimPro Coach unlocks:
# 4     MySwimPro Coach unlocks:
# ...                        ...
# 9211            Follow friends
# 9212            Follow friends
# 9213            Follow friends
# 9214            Follow friends
# 9215            Follow friends
#
#                                                  review  similarity score
# 0     Got the app 5 weeks ago and I have made more p...          0.255298
# 1     I am not a competíos swimmer but I enjoy it an...          0.277176
# 2     Very impressed.  As a long time swimmer with a...          0.966862
# 3     Let’s be honest, for many of us, our best comp...          0.255298
# 4     First and foremost SwimPro is a great app with...          0.255298
# ...                                                 ...               ...
# 9211  Do not get this app!  It will work for a while...          0.219814
# 9212  I've used this app 3 times and all 3 times I g...          0.978960
# 9213  I downloaded the app to see if I could use it ...          0.996890
# 9214  App is useless. Cant even log in using email. ...          0.232212
# 9215  The worst,it is ten dollars a month just to un...          0.219977
#
# [9216 rows x 3 columns]
