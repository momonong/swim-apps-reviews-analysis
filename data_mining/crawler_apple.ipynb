# %% [markdown]
# ## 爬蟲結果
# 因為每個app留言數量不同的關係，會有爬出的結果數量不同的狀況，基本上我已經盡力取出最多的評論數，若還有不夠的地方再通知我，可能就要用另外的方法來爬蟲。

# %%
import pandas as pd
import numpy as np
from app_store_scraper import AppStore
import matplotlib.pyplot as plt

# %%
# DuoSwim
duoswim = AppStore(country='gb', app_name='DuoSwim', app_id='1548487050')
duoswim.review(how_many=1000)

print('\n', duoswim.reviews[0], '\n')

duoswimdf = pd.DataFrame(np.array(duoswim.reviews), columns=['review'])
duoswimdf2 = duoswimdf.join(pd.DataFrame(duoswimdf.pop('review').tolist()))
duoswimdf2['platform'] = 'AppStore'

# duoswimdf2 = duoswimdf2.drop('developerResponse', axis=1)
# duoswimdf2 = duoswimdf2.drop('isEdited', axis=1)
# duoswimdf2 = duoswimdf2.drop('userName', axis=1)
# duoswimdf2 = duoswimdf2.drop('date', axis=1)

duoswimdf2.to_csv('duoswim_apple.csv', escapechar='|')
# Out:
# 2023-12-21 15:28:59,446 [INFO] Base - Initialised: AppStore('gb', 'duoswim', 1548487050)
# 2023-12-21 15:28:59,447 [INFO] Base - Ready to fetch reviews from: https://apps.apple.com/gb/app/duoswim/id1548487050
# 2023-12-21 15:28:59,534 [INFO] Base - [id:1548487050] Fetched 18 reviews (18 fetched in total)
#  {'date': datetime.datetime(2023, 2, 16, 16, 47, 48), 'developerResponse': {'id': 34970792, 'body': 'Hi, thanks for your excellent feedback, we really appreciate it. We have some great news! The latest update includes improvements to the Apple Watch layout, so you should no longer miss any information during your workout. The development team are working hard to implement adjustable turnaround times. This will be made available soon. We will keep you updated with our progress. Happy swimming!', 'modified': '2023-02-20T12:47:51Z'}, 'review': 'Fantastic app, it changed my way to workout in the swimming pool. It’s less expensive than others with plenty of workouts for all kinds of swimmers. Helpful and friendly customer service too.\nI would just improve the Apple Watch layout when working out because the top section gets covered by the watch time and water lock sign, so you miss out some info the app displays. \nI also find the pace at which the beginner repetitions are set to be too fast, sometimes I have to pause the workout to be able to catch up. I think it would be great if it could be possible to set our own pace or just have more seconds since it’s for beginners.\nHowever, still a great app and still 5 stars.', 'rating': 5, 'isEdited': False, 'userName': 'Nicola9.4', 'title': 'Amazing app, some improvements needed'}

# %%
duoswimdf2
# Out:
#                   date                                  developerResponse  \
# 0  2023-02-16 16:47:48  {'id': 34970792, 'body': 'Hi, thanks for your ...
# 1  2023-12-01 18:08:43                                                NaN
# 2  2023-01-14 18:32:17  {'id': 34309278, 'body': 'Hi, thanks for your ...
# 3  2022-06-12 10:13:29  {'id': 22703467, 'body': 'Thanks for the feedb...
# 4  2022-06-11 19:02:41  {'id': 30320184, 'body': 'Hi, thank you for yo...
# 5  2022-05-30 08:49:37  {'id': 22703476, 'body': 'Hi, thanks for your ...
# 6  2023-12-01 12:03:04                                                NaN
# 7  2022-06-12 09:45:46  {'id': 22868883, 'body': 'Hi, thanks for your ...
# 8  2023-12-08 10:19:51                                                NaN
# 9  2021-05-11 13:52:59  {'id': 22829454, 'body': 'Hi, thanks for your ...
# 10 2022-01-28 23:24:05  {'id': 27757692, 'body': 'Thank you for your r...
# 11 2021-05-11 10:16:11  {'id': 22832470, 'body': 'Hi, thanks for your ...
# 12 2021-04-29 08:24:46  {'id': 22703486, 'body': 'Hi, thanks for your ...
# 13 2022-01-21 15:18:34  {'id': 30255487, 'body': 'Hi, thanks for your ...
# 14 2021-04-29 14:06:09  {'id': 22703482, 'body': 'Thanks for the feedb...
# 15 2021-05-18 11:06:46  {'id': 22908559, 'body': 'Hi, thanks for your ...
# 16 2022-01-22 14:37:57  {'id': 30255458, 'body': 'Thanks for the feedb...
# 17 2022-01-21 14:24:20  {'id': 30255473, 'body': 'Hi, thanks for your ...
#
#                                                review  rating  isEdited  \
# 0   Fantastic app, it changed my way to workout in...       5     False
# 1   Brilliant app which not only looks great but w...       5     False
# 2   Positive: The coaching side seems ok and decen...       2     False
# 3   Finally a swim app that looks great and provid...       5      True
# 4   This app is very easy to use. I love how you c...       5     False
# 5   Perfect app. Used to love swimming but hadn’t ...       5      True
# 6   Was looking for fresh ideas for open water swi...       5     False
# 7   After trying a few apps for my swimming, the D...       5      True
# 8   Great app for when looking to get back in the ...       5     False
# 9   This is the first app I have found where I can...       5     False
# 10  Very nice app not so complicated as others. I ...       5     False
# 11  This app was exactly what I needed to start tr...       5     False
# 12  I currently swim 2-3 times a week and this app...       5     False
# 13  This app is quality, helping me build up my sw...       5     False
# 14  I am so impressed with the variety of programs...       5     False
# 15  I am an experienced swimmer and this app has s...       5     False
# 16  Perfect app for me to start my training journe...       5     False
# 17  Awesome app, great training schemes and graphi...       5     False
#
#         userName                                              title  platform
# 0      Nicola9.4              Amazing app, some improvements needed  AppStore
# 1         kn97xo                                   Highly recommend  AppStore
# 2    Swiss-Swiss  Watch app is very limited, integration apple f...  AppStore
# 3        SCS2608                                    A brilliant app  AppStore
# 4        kjmts01                            Great for all swimmers!  AppStore
# 5       SJS45693           Got me back into the pool - loving it !!  AppStore
# 6       Etisweti                                          Great app  AppStore
# 7   mrmatts96011                                  Best swimming app  AppStore
# 8   Benmiddleton                                          Great app  AppStore
# 9      JackH2408                     Amazing tool for swim training  AppStore
# 10      Irene Ts                                         5 star App  AppStore
# 11      Sez-1990                                Just what I needed!  AppStore
# 12     NJS456321                            Brilliant Swimming App!  AppStore
# 13     alexN2202                                            Amazing  AppStore
# 14        j.law7                Fantastic customised swim training!  AppStore
# 15  SophielouCal                       The best swimming coach app!  AppStore
# 16     SarahLNew                                        Perfect app  AppStore
# 17        x14ntn                                     Duo app classy  AppStore

# %%
print(f'latest review timestamp: {max(duoswimdf2["date"])}')
print(f'oldest review timestamp: {min(duoswimdf2["date"])}')
print(f'the number of reviews: {len(duoswimdf2)}')
duoswimdf2['date']
# Out:
# latest review timestamp: 2023-12-08 10:19:51
# oldest review timestamp: 2021-04-29 08:24:46
# the number of reviews: 18
# 0    2023-02-16 16:47:48
# 1    2023-12-01 18:08:43
# 2    2023-01-14 18:32:17
# 3    2022-06-12 10:13:29
# 4    2022-06-11 19:02:41
# 5    2022-05-30 08:49:37
# 6    2023-12-01 12:03:04
# 7    2022-06-12 09:45:46
# 8    2023-12-08 10:19:51
# 9    2021-05-11 13:52:59
# 10   2022-01-28 23:24:05
# 11   2021-05-11 10:16:11
# 12   2021-04-29 08:24:46
# 13   2022-01-21 15:18:34
# 14   2021-04-29 14:06:09
# 15   2021-05-18 11:06:46
# 16   2022-01-22 14:37:57
# 17   2022-01-21 14:24:20
# Name: date, dtype: datetime64[ns]

# %%
duoswim_2023_cnt = 0
duoswim_2022_cnt = 0
duoswim_2021_cnt = 0

for timestamp in duoswimdf2['date']:
    yr = timestamp.year
    if yr==2023:
        duoswim_2023_cnt += 1
    elif yr==2022:
        duoswim_2022_cnt += 1
    else:
        duoswim_2021_cnt += 1

print(f'2023: {duoswim_2023_cnt}\n2022: {duoswim_2022_cnt}\n2021: {duoswim_2021_cnt}')
# Out:
# 2023: 5
# 2022: 8
# 2021: 5

# %%
duoswim_x = [duoswim_2021_cnt, duoswim_2022_cnt, duoswim_2023_cnt]

def func(each, all):
  t = int((each*sum(all)/100))                  # 透過百分比反推原本的數值
  return f'{each:.1f}%\n({t} reviews)'    # 使用文字格式化的方式，顯示內容


plt.pie(duoswim_x,
        radius=1.5,
        labels=[2021, 2022, 2023],
        textprops={'color':'black', 'weight':'bold', 'size':11},  # 設定文字樣式
        autopct=lambda i: func(i,duoswim_x),
        wedgeprops={'linewidth':3,'edgecolor':'w'})

plt.show()

# %%
# MySwimPro
myswimpro = AppStore(country='us', app_name='MySwimPro', app_id='994386450')
myswimpro.review(how_many=3800)

print(myswimpro.reviews[0])

myswimprodf = pd.DataFrame(np.array(myswimpro.reviews), columns=['review'])
myswimprodf2 = myswimprodf.join(pd.DataFrame(myswimprodf.pop('review').tolist()))
myswimprodf2['platform'] = 'AppStore'

# myswimprodf2 = myswimprodf2.drop('developerResponse', axis=1)
# myswimprodf2 = myswimprodf2.drop('isEdited', axis=1)
# myswimprodf2 = myswimprodf2.drop('userName', axis=1)
# myswimprodf2 = myswimprodf2.drop('date', axis=1)

myswimprodf2.to_csv('myswimpro_apple.csv', escapechar='|')
# Out:
# 2023-12-21 15:28:59,809 [INFO] Base - Initialised: AppStore('us', 'myswimpro', 994386450)
# 2023-12-21 15:28:59,810 [INFO] Base - Ready to fetch reviews from: https://apps.apple.com/us/app/myswimpro/id994386450
# 2023-12-21 15:29:01,983 [INFO] Base - [id:994386450] Fetched 516 reviews (516 fetched in total)
# {'date': datetime.datetime(2023, 1, 27, 22, 31, 43), 'review': 'Got the app 5 weeks ago and I have made more progress in that time than the whole 1.5 years of swimming on my own before. The customized coaching is great and the app certainly pushes you but never has unreasonably high expectations of you. The ability to customize what goals you are working towards, how often you swim, how fast you swim, and what strokes you swim are all excellent features. Only negative I’ve experienced is minor bugs with sync issues between the app and my smartwatch. This hasn’t impacted my ability to use all the features just needed to use work arounds with how the workout is accessed by the watch. Minor bugs stop me from giving it a 5* but I am still loving the app. If I could see some additional features the biggest would be the ability to go back a set/split in a workout. Sometimes I can’t keep up with the times it says and I fall behind so this would help keep me on track. Also, the ability to toggle which swim equipment you have access to. My pool offers kick boards and pullbouys but no fins or paddles and I’d imagine it varies for everyone.', 'rating': 4, 'isEdited': False, 'userName': 'Rcote33', 'title': 'My Swim Pro Review'}

# %%
myswimprodf2
# Out:
#                    date                                             review  \
# 0   2023-01-27 22:31:43  Got the app 5 weeks ago and I have made more p...
# 1   2023-08-29 11:46:37  I am not a competíos swimmer but I enjoy it an...
# 2   2023-03-15 19:44:28  Very impressed.  As a long time swimmer with a...
# 3   2019-11-12 20:14:20  Let’s be honest, for many of us, our best comp...
# 4   2019-04-27 01:39:13  I use this app with my Apple watch 3. It autom...
# ..                  ...                                                ...
# 511 2019-08-31 01:41:24  Do not get this app!  It will work for a while...
# 512 2017-01-02 22:18:43  I've used this app 3 times and all 3 times I g...
# 513 2018-08-21 18:36:42  I downloaded the app to see if I could use it ...
# 514 2018-07-16 23:13:00  App is useless. Cant even log in using email. ...
# 515 2016-07-31 15:02:51  The worst,it is ten dollars a month just to un...
#
#      rating  isEdited       userName  \
# 0         4     False        Rcote33
# 1         5     False   BlehBlihBluh
# 2         5     False    Kickstand21
# 3         5     False         mtbosu
# 4         5     False    granitedive
# ..      ...       ...            ...
# 511       1     False     Tommmcatt
# 512       5     False            LIG
# 513       1     False       Fortryan
# 514       1     False       wasted21
# 515       1     False  Awesome MAN💪🏻
#
#                                                  title  \
# 0                                   My Swim Pro Review
# 1                                     Great investment
# 2                           From Analytics to Coaching
# 3    You can’t believe all that’s packed into this ...
# 4                        Great for Pool and Open Water
# ..                                                 ...
# 511             Very Buggy and Incredibly Disapointing
# 512                                       Dissatisfied
# 513        DO NOT DOWNLOAD THE APP AND THEN CANCEL!!!!
# 514                                      Disappointing
# 515                                           Horrible
#
#                                      developerResponse  platform
# 0                                                  NaN  AppStore
# 1    {'id': 38880940, 'body': 'Thank you for taking...  AppStore
# 2                                                  NaN  AppStore
# 3                                                  NaN  AppStore
# 4                                                  NaN  AppStore
# ..                                                 ...       ...
# 511  {'id': 10447717, 'body': 'Hi there, thank you ...  AppStore
# 512                                                NaN  AppStore
# 513  {'id': 4932932, 'body': 'So sorry to hear abou...  AppStore
# 514  {'id': 4360082, 'body': 'Hi wasted21, sorry ab...  AppStore
# 515                                                NaN  AppStore
#
# [516 rows x 8 columns]

# %%
print(f'latest review timestamp: {max(myswimprodf2["date"])}')
print(f'oldest review timestamp: {min(myswimprodf2["date"])}')
print(f'the number of reviews: {len(myswimprodf2)}')
myswimprodf2['date']
# Out:
# latest review timestamp: 2023-12-11 18:22:26
# oldest review timestamp: 2015-06-15 12:43:25
# the number of reviews: 516
# 0     2023-01-27 22:31:43
# 1     2023-08-29 11:46:37
# 2     2023-03-15 19:44:28
# 3     2019-11-12 20:14:20
# 4     2019-04-27 01:39:13
#               ...
# 511   2019-08-31 01:41:24
# 512   2017-01-02 22:18:43
# 513   2018-08-21 18:36:42
# 514   2018-07-16 23:13:00
# 515   2016-07-31 15:02:51
# Name: date, Length: 516, dtype: datetime64[ns]

# %%
myswimpro_2023_cnt = 0
myswimpro_2022_cnt = 0
myswimpro_2021_cnt = 0
myswimpro_2020_cnt = 0
myswimpro_2019_cnt = 0
myswimpro_2018_cnt = 0
myswimpro_2017_cnt = 0
myswimpro_2016_cnt = 0
myswimpro_2015_cnt = 0


for timestamp in myswimprodf2['date']:
    yr = timestamp.year
    if yr==2023:
        myswimpro_2023_cnt += 1
    elif yr==2022:
        myswimpro_2022_cnt += 1
    elif yr==2021:
        myswimpro_2021_cnt += 1
    elif yr==2020:
        myswimpro_2020_cnt += 1
    elif yr==2019:
        myswimpro_2019_cnt += 1
    elif yr==2018:
        myswimpro_2018_cnt += 1
    elif yr==2017:
        myswimpro_2017_cnt += 1
    elif yr==2016:
        myswimpro_2016_cnt += 1
    else:
        myswimpro_2015_cnt += 1


print(myswimpro_2023_cnt, myswimpro_2022_cnt, myswimpro_2021_cnt, myswimpro_2020_cnt, myswimpro_2019_cnt, myswimpro_2018_cnt, myswimpro_2017_cnt, myswimpro_2016_cnt, myswimpro_2015_cnt)
# Out:
# 46 77 61 56 73 59 76 45 23

# %%
myswimpro_x = [myswimpro_2023_cnt, myswimpro_2022_cnt, myswimpro_2021_cnt, myswimpro_2020_cnt, myswimpro_2019_cnt, myswimpro_2018_cnt, myswimpro_2017_cnt, myswimpro_2016_cnt, myswimpro_2015_cnt]

def func(each, all):
  t = int((each*sum(all)/100))                  # 透過百分比反推原本的數值
  return f'{each:.1f}%\n({t} reviews)'    # 使用文字格式化的方式，顯示內容


plt.pie(myswimpro_x,
        radius=1.5,
        labels=[2023, 2022, 2021, 2020, 2019, 2018, 2017, 2016, 2015],
        textprops={'color':'black', 'weight':'bold', 'size':9},  # 設定文字樣式
        autopct=lambda i: func(i,myswimpro_x),
        wedgeprops={'linewidth':3,'edgecolor':'w'})

plt.show()

# %%
# Swim.com
swimcom = AppStore(country='us', app_name='Swim.com', app_id='956030704')
swimcom.review(how_many=1000)

print(swimcom.reviews[0])

swimcomdf = pd.DataFrame(np.array(swimcom.reviews), columns=['review'])
swimcomdf2 = swimcomdf.join(pd.DataFrame(swimcomdf.pop('review').tolist()))
swimcomdf2['platform'] = 'AppStore'

# swimcomdf2 = swimcomdf2.drop('developerResponse', axis=1)
# swimcomdf2 = swimcomdf2.drop('isEdited', axis=1)
# swimcomdf2 = swimcomdf2.drop('userName', axis=1)
# swimcomdf2 = swimcomdf2.drop('date', axis=1)

swimcomdf2.to_csv('swim-com_apple.csv', escapechar='|')
# Out:
# 2023-12-21 15:29:02,253 [INFO] Base - Initialised: AppStore('us', 'swim-com', 956030704)
# 2023-12-21 15:29:02,254 [INFO] Base - Ready to fetch reviews from: https://apps.apple.com/us/app/swim-com/id956030704
# 2023-12-21 15:29:03,082 [INFO] Base - [id:956030704] Fetched 234 reviews (234 fetched in total)
# {'date': datetime.datetime(2018, 10, 15, 14, 50, 36), 'developerResponse': {'id': 6236997, 'body': 'Thank you for your feedback. We recently released version 2.3.2 which fixed the tracking issue for Apple Watch users. In addition, we recently (Friday of last week) completed revision of our technology roadmap and feature set. Expect to see several changes implemented over the next 60 days. These changes will significantly enhance our analytics capabilities including more detailed breakdown by different parameters. \n\nPlease keep sharing your feedback and ideas for enhancement. We are listening and engaging with our users to help develop our roadmap and beta test changes.', 'modified': '2018-12-04T13:37:26Z'}, 'review': "After using this app for two years on a Pebble watch, it was hit or miss.  Moving on to an Apple Watch 2, the interface was better but motion tracking and distance recording was only slightly better.  Recent updates under iOS 12 and WatchOS 5 give much better tracking in the pool.  I still get occasional phantom laps added but overall, length tracking is very good.\n\nThe app still cannot distinguish my breaststroke from freestyle.  So frustrating. \n\nI wish the app allowed better data analysis of multiple workouts over a period of months, like being able to chart swolf for all of my swims.  I’m not a competitive swimmer so many of the apps features don't appeal to me.  I just don't understand why I cant look at the pace of all my freestyle sessions over time and see if I’m improving.", 'rating': 4, 'isEdited': False, 'userName': 'ENC iOS Reviews', 'title': 'Improved tracking but data analysis still weak'}

# %%
swimcomdf2
# Out:
#                    date                                  developerResponse  \
# 0   2018-10-15 14:50:36  {'id': 6236997, 'body': 'Thank you for your fe...
# 1   2019-07-23 14:42:06  {'id': 9921973, 'body': 'Thanks for the critic...
# 2   2023-04-25 01:11:37  {'id': 36195179, 'body': 'Hello Boymom4367. We...
# 3   2020-07-28 14:19:24  {'id': 16984534, 'body': 'You are an inspirati...
# 4   2018-03-04 18:09:33                                                NaN
# ..                  ...                                                ...
# 229 2019-03-02 23:55:00  {'id': 7591209, 'body': 'Hi Alex. Sorry to hea...
# 230 2018-09-30 20:31:47                                                NaN
# 231 2017-02-10 17:59:18                                                NaN
# 232 2016-07-18 14:54:35                                                NaN
# 233 2016-01-02 18:59:18                                                NaN
#
#                                                 review  rating  isEdited  \
# 0    After using this app for two years on a Pebble...       4     False
# 1    Strictly from an App Design standpoint, it bre...       3     False
# 2    They’ve made some good improvements to the app...       4     False
# 3    At 70 yo I sometimes ( no, all the time) need ...       5     False
# 4    This app has all the potential of being great ...       2     False
# ..                                                 ...     ...       ...
# 229  I have used this app with my old Apple Watch S...       2     False
# 230  I want to use this app. I love swim.com and us...       2     False
# 231  ***Update - 02-10-2017\nMore updates have been...       2     False
# 232  App.has gone from functional to brick. Says it...       2     False
# 233  It's January now and I haven't been able to sy...       1     False
#
#             userName                                           title  platform
# 0    ENC iOS Reviews  Improved tracking but data analysis still weak  AppStore
# 1          永魅礼の月明かり兎         It has potential, but still needs work.  AppStore
# 2         Boymom4367  Good, but a little wonky with stroke detection  AppStore
# 3      cupcake-maker                           Use it for motivation  AppStore
# 4       TheeFrenchie                                Inaccurate/buggy  AppStore
# ..               ...                                             ...       ...
# 229        Alextheoc                   Tracking still way off for me  AppStore
# 230        CMolnar65                      Inaccurate stroke accuracy  AppStore
# 231      Immeherenow                  Great Concept. Poor Execution.  AppStore
# 232   Die_Fledermaus                                        Dead app  AppStore
# 233        gbraymond                     Poor experience with Pebble  AppStore
#
# [234 rows x 8 columns]

# %%
print(f'latest review timestamp: {max(swimcomdf2["date"])}')
print(f'oldest review timestamp: {min(swimcomdf2["date"])}')
print(f'the number of reviews: {len(swimcomdf2)}')
swimcomdf2['date']
# Out:
# latest review timestamp: 2023-11-19 23:15:07
# oldest review timestamp: 2015-04-17 22:49:16
# the number of reviews: 234
# 0     2018-10-15 14:50:36
# 1     2019-07-23 14:42:06
# 2     2023-04-25 01:11:37
# 3     2020-07-28 14:19:24
# 4     2018-03-04 18:09:33
#               ...
# 229   2019-03-02 23:55:00
# 230   2018-09-30 20:31:47
# 231   2017-02-10 17:59:18
# 232   2016-07-18 14:54:35
# 233   2016-01-02 18:59:18
# Name: date, Length: 234, dtype: datetime64[ns]

# %%
swimcom_2023_cnt = 0
swimcom_2022_cnt = 0
swimcom_2021_cnt = 0
swimcom_2020_cnt = 0
swimcom_2019_cnt = 0
swimcom_2018_cnt = 0
swimcom_2017_cnt = 0
swimcom_2016_cnt = 0
swimcom_2015_cnt = 0


for timestamp in swimcomdf2['date']:
    yr = timestamp.year
    if yr==2023:
        swimcom_2023_cnt += 1
    elif yr==2022:
        swimcom_2022_cnt += 1
    elif yr==2021:
        swimcom_2021_cnt += 1
    elif yr==2020:
        swimcom_2020_cnt += 1
    elif yr==2019:
        swimcom_2019_cnt += 1
    elif yr==2018:
        swimcom_2018_cnt += 1
    elif yr==2017:
        swimcom_2017_cnt += 1
    elif yr==2016:
        swimcom_2016_cnt += 1
    else:
        swimcom_2015_cnt += 1


print(swimcom_2023_cnt, swimcom_2022_cnt, swimcom_2021_cnt, swimcom_2020_cnt, swimcom_2019_cnt, swimcom_2018_cnt, swimcom_2017_cnt, swimcom_2016_cnt, swimcom_2015_cnt)
# Out:
# 16 16 20 24 32 14 56 47 9

# %%
swimcom_x = [swimcom_2023_cnt, swimcom_2022_cnt, swimcom_2021_cnt, swimcom_2020_cnt, swimcom_2019_cnt, swimcom_2018_cnt, swimcom_2017_cnt, swimcom_2016_cnt, swimcom_2015_cnt]

def func(each, all):
  t = int((each*sum(all)/100))                  # 透過百分比反推原本的數值
  return f'{each:.1f}%\n({t} reviews)'    # 使用文字格式化的方式，顯示內容


plt.pie(swimcom_x,
        radius=1.5,
        labels=[2023, 2022, 2021, 2020, 2019, 2018, 2017, 2016, 2015],
        textprops={'color':'black', 'weight':'bold', 'size':9},  # 設定文字樣式
        autopct=lambda i: func(i,swimcom_x),
        wedgeprops={'linewidth':3,'edgecolor':'w'})

plt.show()

# %%
# FORM
form = AppStore(country='us', app_name='FORM Swim', app_id='1321117442')
form.review(how_many=2100)

print(form.reviews[0])

formdf = pd.DataFrame(np.array(form.reviews), columns=['review'])
formdf2 = formdf.join(pd.DataFrame(formdf.pop('review').tolist()))
formdf2['platform'] = 'AppStore'

# formdf2 = formdf2.drop('developerResponse', axis=1)
# formdf2 = formdf2.drop('isEdited', axis=1)
# formdf2 = formdf2.drop('userName', axis=1)
# formdf2 = formdf2.drop('date', axis=1)

formdf2.to_csv('form-swim_apple.csv', escapechar='|')
# Out:
# 2023-12-21 15:29:03,288 [INFO] Base - Initialised: AppStore('us', 'form-swim', 1321117442)
# 2023-12-21 15:29:03,288 [INFO] Base - Ready to fetch reviews from: https://apps.apple.com/us/app/form-swim/id1321117442
# 2023-12-21 15:29:03,589 [INFO] Base - [id:1321117442] Fetched 62 reviews (62 fetched in total)
# {'date': datetime.datetime(2020, 8, 4, 11, 7, 47), 'developerResponse': {'id': 17008952, 'body': 'Thanks for your awesome feedback!', 'modified': '2020-07-31T17:09:09Z'}, 'review': 'I like sport gadgets, but usually 9 out of 10 times my enthusiasm ends in great disappointment. However, the Form swim goggles have by far exceeded my expectations - they simply work. All the features advertised work better than expected and the app is a solid companion of the goggles. If you want to focus on your swim and forget counting laps or looking up for your time, the Form swim goggles are the best solution. They are also for me personally one of the best fitting goggles I’ve ever used, but that might be different for others people. I am really grateful for the team having developed these goggles. I wish more people knew about them. They are now also sold in Europe, but I was able to order them from the US.\nP. S. : last week I tried out the new open water feature after a firmware update. I connected my Form goggle with my Apple Watch series 4 and went for a first swim. Once again, it all worked as announced. Just as a suggestion, I really wish that the developers could use Apple Watch’s inbuilt compass to show the direction of my swim on the display too. It’s my only future feature request!', 'rating': 5, 'isEdited': True, 'title': 'Amazing! Now even better 😃', 'userName': 'armanbn'}

# %%
formdf2
# Out:
#                   date                                  developerResponse  \
# 0  2020-08-04 11:07:47  {'id': 17008952, 'body': 'Thanks for your awes...
# 1  2021-08-02 17:08:07  {'id': 24544052, 'body': 'Thanks so much for y...
# 2  2020-11-25 14:41:27  {'id': 19705387, 'body': 'Thank you for your r...
# 3  2022-08-31 15:57:28  {'id': 34622430, 'body': 'Thanks for these com...
# 4  2023-03-13 06:25:25  {'id': 35534710, 'body': 'Thanks for your feed...
# ..                 ...                                                ...
# 57 2019-08-11 16:56:51  {'id': 10264693, 'body': 'Edit: This issue has...
# 58 2023-04-05 18:22:18  {'id': 36147828, 'body': 'Thanks for your revi...
# 59 2021-09-30 00:45:51  {'id': 25536008, 'body': 'Thanks for your revi...
# 60 2020-11-13 12:30:30  {'id': 19705380, 'body': 'Thanks for your awes...
# 61 2019-08-14 21:59:42                                                NaN
#
#                                                review  rating  isEdited  \
# 0   I like sport gadgets, but usually 9 out of 10 ...       5      True
# 1   My biggest question was if I was going to be a...       5     False
# 2   This has been a game changer in how I swim. Fi...       5     False
# 3   The googles are fine and the workout generatio...       3     False
# 4   This and bone conduction headphones have me sw...       5     False
# ..                                                ...     ...       ...
# 57                              As described in title       1     False
# 58  It recognizes freestyle but all my breast stro...       1     False
# 59  Great goggles, but major sync issues to Apple ...       2     False
# 60  I was excited when I first saw the Form goggle...       5     False
# 61                          Great app, great goggles!       5     False
#
#                                                 title            userName  \
# 0                          Amazing! Now even better 😃             armanbn
# 1                                     Very motivating           Audiguy01
# 2                                I love these goggles           Microserf
# 3                    It’s fine, but not revolutionary              dpquik
# 4             Made me fall back in love with swimming         Robbie dm54
# ..                                                ...                 ...
# 57  Unable to select goggle name in pairing setup....           MalcolmCL
# 58                            Bad at stroke detection              mcomte
# 59                      Does not sync to Apple Health  italiagirlkaterina
# 60                                Great Training Tech              Nuppy1
# 61                          Great app, great goggles!             SYNIK99
#
#     platform
# 0   AppStore
# 1   AppStore
# 2   AppStore
# 3   AppStore
# 4   AppStore
# ..       ...
# 57  AppStore
# 58  AppStore
# 59  AppStore
# 60  AppStore
# 61  AppStore
#
# [62 rows x 8 columns]

# %%
print(f'latest review timestamp: {max(formdf2["date"])}')
print(f'oldest review timestamp: {min(formdf2["date"])}')
print(f'the number of reviews: {len(formdf2)}')
formdf2['date']
# Out:
# latest review timestamp: 2023-12-14 15:56:45
# oldest review timestamp: 2019-08-11 16:56:51
# the number of reviews: 62
# 0    2020-08-04 11:07:47
# 1    2021-08-02 17:08:07
# 2    2020-11-25 14:41:27
# 3    2022-08-31 15:57:28
# 4    2023-03-13 06:25:25
#              ...
# 57   2019-08-11 16:56:51
# 58   2023-04-05 18:22:18
# 59   2021-09-30 00:45:51
# 60   2020-11-13 12:30:30
# 61   2019-08-14 21:59:42
# Name: date, Length: 62, dtype: datetime64[ns]

# %%
form_2023_cnt = 0
form_2022_cnt = 0
form_2021_cnt = 0
form_2020_cnt = 0
form_2019_cnt = 0



for timestamp in swimcomdf2['date']:
    yr = timestamp.year
    if yr==2023:
        form_2023_cnt += 1
    elif yr==2022:
        form_2022_cnt += 1
    elif yr==2021:
        form_2021_cnt += 1
    elif yr==2020:
        form_2020_cnt += 1
    else:
        form_2019_cnt += 1


print(form_2023_cnt, form_2022_cnt, form_2021_cnt, form_2020_cnt, swimcom_2019_cnt)
# Out:
# 16 16 20 24 32

# %%
form_x = [form_2023_cnt, form_2022_cnt, form_2021_cnt, form_2020_cnt, swimcom_2019_cnt]

def func(each, all):
  t = int((each*sum(all)/100))                  # 透過百分比反推原本的數值
  return f'{each:.1f}%\n({t} reviews)'    # 使用文字格式化的方式，顯示內容


plt.pie(form_x,
        radius=1.5,
        labels=[2023, 2022, 2021, 2020, 2019],
        textprops={'color':'black', 'weight':'bold', 'size':10},  # 設定文字樣式
        autopct=lambda i: func(i,form_x),
        wedgeprops={'linewidth':3,'edgecolor':'w'})

plt.show()

# %%
# SwimUp
swimup = AppStore(country='us', app_name='SwimUp', app_id='1477061412')
swimup.review(how_many=50)

print(swimup.reviews[0])

swimupdf = pd.DataFrame(np.array(swimup.reviews), columns=['review'])
swimupdf2 = swimupdf.join(pd.DataFrame(swimupdf.pop('review').tolist()))
swimupdf2['platform'] = 'AppStore'

# swimupdf2 = swimupdf2.drop('developerResponse', axis=1)
# swimupdf2 = swimupdf2.drop('isEdited', axis=1)
# swimupdf2 = swimupdf2.drop('userName', axis=1)
# swimupdf2 = swimupdf2.drop('date', axis=1)

swimupdf2.to_csv('swimup_apple.csv', escapechar='|')
# Out:
# 2023-12-21 15:29:03,856 [INFO] Base - Initialised: AppStore('us', 'swimup', 1477061412)
# 2023-12-21 15:29:03,856 [INFO] Base - Ready to fetch reviews from: https://apps.apple.com/us/app/swimup/id1477061412
# 2023-12-21 15:29:03,968 [INFO] Base - [id:1477061412] Fetched 9 reviews (9 fetched in total)
# {'date': datetime.datetime(2023, 5, 7, 17, 56), 'developerResponse': {'id': 40030804, 'body': 'Thank you very much for your feedback! :)', 'modified': '2023-11-09T11:41:25Z'}, 'review': 'Amazing app, amazing coach and superb courses. I am enjoying the app so much and it motivates me to go at least twice a week for swim. I find courses are very well made and help any aspiring swimmer at all levels. \nI used to swim but the coach had changed my swim style and technique so much and it improved my swimming endurance and skill to a great extent. \nThank you for the wonderful service. The subscription is very well worth. In fact I would say you get lot more than you pay if you are persistent with the workouts and the courses', 'rating': 5, 'isEdited': False, 'title': 'Amazing app', 'userName': 'satheeshka'}

# %%
swimupdf2
# Out:
#                  date                                  developerResponse  \
# 0 2023-05-07 17:56:00  {'id': 40030804, 'body': 'Thank you very much ...
# 1 2023-12-14 10:50:01  {'id': 40718846, 'body': 'Thank you for your r...
# 2 2022-01-19 21:25:36  {'id': 31348313, 'body': 'Thanks for your feed...
# 3 2023-04-04 14:55:04  {'id': 40030924, 'body': 'Thank you for your r...
# 4 2020-02-17 07:20:49  {'id': 13746830, 'body': 'Thanks for feedback!...
# 5 2023-05-04 14:25:04  {'id': 40030884, 'body': 'Thank you for your r...
# 6 2021-10-04 01:08:58  {'id': 31348318, 'body': 'Thanks for your supp...
# 7 2021-08-01 05:34:55  {'id': 31348363, 'body': 'Hi, thank you for th...
# 8 2021-12-09 13:54:33  {'id': 40030995, 'body': 'Thank you for your r...
#
#                                               review  rating  isEdited  \
# 0  Amazing app, amazing coach and superb courses....       5     False
# 1  Learning to swim has been such an amazing jour...       5     False
# 2  Tried a few training apps for getting into swi...       5     False
# 3  I have been trying to learn how to freestyle w...       4     False
# 4  Great app! Simple as it is, works good for beg...       5     False
# 5  They put me on 2 levels before champion but th...       2     False
# 6              Thank you guys. Appreciate your work.       5     False
# 7  I love Swimup’s YouTube channel so I was reall...       3     False
# 8     No voice tutorials makes these videos useless.       1     False
#
#                                              title               userName  \
# 0                                      Amazing app             satheeshka
# 1                                         Good app                Ulricen
# 2                                Best swimming app               Nickm10_
# 3                                       Thank you!               lalamo25
# 4                                   Easy-peasy app  Dan "Awesome swimmer"
# 5  Honest oppinion of a 17 year old on a swim team       Potato Salad 321
# 6                                       Great App.            Kliufinskyi
# 7       I really want to like the app, I really do          cherrydiamzon
# 8                                         No voice                  zxz2x
#
#    platform
# 0  AppStore
# 1  AppStore
# 2  AppStore
# 3  AppStore
# 4  AppStore
# 5  AppStore
# 6  AppStore
# 7  AppStore
# 8  AppStore

# %%
print(f'latest review timestamp: {max(swimupdf2["date"])}')
print(f'oldest review timestamp: {min(swimupdf2["date"])}')
print(f'the number of reviews: {len(swimupdf2)}')
swimupdf2['date']
# Out:
# latest review timestamp: 2023-12-14 10:50:01
# oldest review timestamp: 2020-02-17 07:20:49
# the number of reviews: 9
# 0   2023-05-07 17:56:00
# 1   2023-12-14 10:50:01
# 2   2022-01-19 21:25:36
# 3   2023-04-04 14:55:04
# 4   2020-02-17 07:20:49
# 5   2023-05-04 14:25:04
# 6   2021-10-04 01:08:58
# 7   2021-08-01 05:34:55
# 8   2021-12-09 13:54:33
# Name: date, dtype: datetime64[ns]

# %%
swimup_2023_cnt = 0
swimup_2022_cnt = 0
swimup_2021_cnt = 0
swimup_2020_cnt = 0

for timestamp in swimupdf2['date']:
    yr = timestamp.year
    if yr==2023:
        swimup_2023_cnt += 1
    elif yr==2022:
        swimup_2022_cnt += 1
    elif yr==2021:
        swimup_2021_cnt += 1
    else:
        swimup_2020_cnt += 1

print(swimup_2023_cnt, swimup_2022_cnt, swimup_2021_cnt, swimup_2020_cnt)
# Out:
# 4 1 3 1

# %%
swimup_x = [swimup_2023_cnt, swimup_2022_cnt, swimup_2021_cnt, swimup_2020_cnt]

def func(each, all):
  t = int((each*sum(all)/100))                  # 透過百分比反推原本的數值
  return f'{each:.1f}%\n({t} reviews)'    # 使用文字格式化的方式，顯示內容


plt.pie(swimup_x,
        radius=1.5,
        labels=[2023, 2022, 2021, 2020],
        textprops={'color':'black', 'weight':'bold', 'size':10},  # 設定文字樣式
        autopct=lambda i: func(i,swimup_x),
        wedgeprops={'linewidth':3,'edgecolor':'w'})

plt.show()

# %% [markdown]
# ## 關鍵字分析
# 這邊用一些簡單的分析，供你們參考

# %%
this is a breakpoint
# Out:
#   Cell In[55], line 1
#     this is a breakpoint
#               ^
# SyntaxError: invalid syntax

# %%
import yake
from keybert import KeyBERT

# %%
kw_model = KeyBERT(model='all-mpnet-base-v2')
# Out:
# 2023-09-03 00:38:12,258 [INFO] sentence_transformers.SentenceTransformer - Load pretrained SentenceTransformer: all-mpnet-base-v2
# Downloading (…)a8e1d/.gitattributes: 100%|██████████| 1.18k/1.18k [00:00<00:00, 1.50MB/s]
# Downloading (…)_Pooling/config.json: 100%|██████████| 190/190 [00:00<00:00, 411kB/s]
# Downloading (…)b20bca8e1d/README.md: 100%|██████████| 10.6k/10.6k [00:00<00:00, 16.0MB/s]
# Downloading (…)0bca8e1d/config.json: 100%|██████████| 571/571 [00:00<00:00, 1.49MB/s]
# Downloading (…)ce_transformers.json: 100%|██████████| 116/116 [00:00<00:00, 232kB/s]
# Downloading (…)e1d/data_config.json: 100%|██████████| 39.3k/39.3k [00:00<00:00, 203kB/s]
# Downloading pytorch_model.bin: 100%|██████████| 438M/438M [00:22<00:00, 19.4MB/s]
# Downloading (…)nce_bert_config.json: 100%|██████████| 53.0/53.0 [00:00<00:00, 86.0kB/s]
# Downloading (…)cial_tokens_map.json: 100%|██████████| 239/239 [00:00<00:00, 691kB/s]
# Downloading (…)a8e1d/tokenizer.json: 100%|██████████| 466k/466k [00:00<00:00, 2.22MB/s]
# Downloading (…)okenizer_config.json: 100%|██████████| 363/363 [00:00<00:00, 587kB/s]
# Downloading (…)8e1d/train_script.py: 100%|██████████| 13.1k/13.1k [00:00<00:00, 21.3MB/s]
# Downloading (…)b20bca8e1d/vocab.txt: 100%|██████████| 232k/232k [00:00<00:00, 594kB/s]
# Downloading (…)bca8e1d/modules.json: 100%|██████████| 349/349 [00:00<00:00, 954kB/s]
# 2023-09-03 00:38:45,440 [INFO] sentence_transformers.SentenceTransformer - Use pytorch device: cpu

# %%
# original output of the model
keywords = kw_model.extract_keywords(text, 
                                     keyphrase_ngram_range=(1, 2), 
                                     stop_words='english', 
                                     highlight=True,
                                     top_n=10,)
colored_text = keywords

keywords_list= list(dict(keywords).keys())
print(keywords_list)
# Out:
# Amazing app coach and superb courses am enjoying the app so much and it motivates me to go at least twice week for
# swim find courses are very well made and help any aspiring swimmer all levels used to swim but the coach had
# changed my swim style and technique so much and it improved my swimming endurance and skill to great extent Thank
# you for the wonderful service The subscription is very well worth In fact would say you get lot more than you pay
# if you are persistent with the workouts and the courses
# ['enjoying app', 'subscription worth', 'swim courses', 'amazing app', 'aspiring swimmer', 'improved swimming', 'app amazing', 'swim coach', 'used swim', 'week swim']

# %%
# DuoSwim
duoswimls = [duoswimdf2['review'][i] for i in range(len(duoswimdf2))]
duoswimdf2['keywords_by_method1'] = duoswimls
duoswimdf2['keywords_by_method2'] = duoswimls
for i in range(len(duoswimdf2)):
    # method 1
    kw_extractor = yake.KeywordExtractor(top=10, stopwords=None)
    keywords1 = kw_extractor.extract_keywords(text=duoswimls[i])
    keywords_list1 = []
    for kw, v in keywords1:
        keywords_list1.append(kw)
    duoswimdf2['keywords_by_method1'][i] = keywords_list1
    # method 2
    keywords2 = kw_model.extract_keywords(duoswimls[i], 
                                     keyphrase_ngram_range=(1, 2), 
                                     stop_words='english', 
                                     highlight=True,
                                     top_n=10)
    keywords_list2 = list(dict(keywords2).keys())
    duoswimdf2['keywords_by_method2'][i] = keywords_list2

# %%
duoswimdf2.to_csv('crawler_result/duoswim_with_keywords.csv', escapechar='|')
duoswimdf2
# Out:
#                                                review  rating  \
# 0   Fantastic app, it changed my way to workout in...       5
# 1   Finally a swim app that looks great and provid...       5
# 2   Positive: The coaching side seems ok and decen...       2
# 3   This app is very easy to use. I love how you c...       5
# 4   Perfect app. Used to love swimming but hadn’t ...       5
# 5   After trying a few apps for my swimming, the D...       5
# 6   This is the first app I have found where I can...       5
# 7   Very nice app not so complicated as others. I ...       5
# 8   This app was exactly what I needed to start tr...       5
# 9   I currently swim 2-3 times a week and this app...       5
# 10  This app is quality, helping me build up my sw...       5
# 11  I am so impressed with the variety of programs...       5
# 12  I am an experienced swimmer and this app has s...       5
# 13  Perfect app for me to start my training journe...       5
# 14  Awesome app, great training schemes and graphi...       5
#
#                                                 title  \
# 0               Amazing app, some improvements needed
# 1                                     A brilliant app
# 2   Watch app is very limited, integration apple f...
# 3                             Great for all swimmers!
# 4            Got me back into the pool - loving it !!
# 5                                   Best swimming app
# 6                      Amazing tool for swim training
# 7                                          5 star App
# 8                                 Just what I needed!
# 9                             Brilliant Swimming App!
# 10                                            Amazing
# 11                Fantastic customised swim training!
# 12                       The best swimming coach app!
# 13                                        Perfect app
# 14                                     Duo app classy
#
#                                   keywords_by_method1  \
# 0   [swimming pool, Fantastic app, Apple Watch lay...
# 1   [superb workouts, Finally a swim, swim app, Fi...
# 2   [decent price compared, decent price, price co...
# 3   [app, phone-watch connected app, Swim, n’t fau...
# 4   [Perfect app, Perfect, n’t regularly swam, app...
# 5   [DuoSwim app, swimming, DuoSwim, favourite, co...
# 6   [follow to improve, training sessions, session...
# 7   [nice app, nice, app, complicated, journey fro...
# 8   [effectively and efficiently, needed to start,...
# 9   [swim 2-3 times, times a week, training plans,...
# 10  [app is quality, good a job, lot cheaper, chea...
# 11  [guide my training, variety of programs, train...
# 12  [experienced swimmer, generated programmes, pr...
# 13  [Perfect app, training journey, start my train...
# 14  [great training schemes, Awesome app, easy to ...
#
#                                   keywords_by_method2
# 0   [fantastic app, great app, apple watch, app st...
# 1   [swim app, apple watch, impressed app, app, sw...
# 2   [rate swim, apple fitness, available swims, sw...
# 3   [workouts watch, apple watch, phone watch, syn...
# 4   [swims times, app used, perfect app, love swim...
# 5   [duoswim app, swimming duoswim, duoswim, apps ...
# 6   [improve swimming, swimming range, training se...
# 7   [nice app, app complicated, format workouts, a...
# 8   [pool app, plans workouts, motivated pool, rec...
# 9   [swim times, currently swim, week app, follow ...
# 10  [pace swimming, build swimming, swimming skill...
# 11  [duo swim, pool duo, swim, swim captured, pool...
# 12  [swimmer app, experienced swimmer, swimmer, ap...
# 13  [app, training journey, perfect app, start tra...
# 14  [awesome app, app great, great training, train...

# %%
# MySwimPro
myswimprols = [myswimprodf2['review'][i] for i in range(len(myswimprodf2))]
myswimprodf2['keywords_by_method1'] = myswimprols
myswimprodf2['keywords_by_method2'] = myswimprols
for i in range(len(myswimprodf2)):
    # method 1
    kw_extractor = yake.KeywordExtractor(top=10, stopwords=None)
    keywords1 = kw_extractor.extract_keywords(text=myswimprols[i])
    keywords_list1 = []
    for kw, v in keywords1:
        keywords_list1.append(kw)
    myswimprodf2['keywords_by_method1'][i] = keywords_list1
    # method 2
    keywords2 = kw_model.extract_keywords(myswimprols[i], 
                                     keyphrase_ngram_range=(1, 2), 
                                     stop_words='english', 
                                     highlight=True,
                                     top_n=10)
    keywords_list2 = list(dict(keywords2).keys())
    myswimprodf2['keywords_by_method2'][i] = keywords_list2

# %%
myswimprodf2.to_csv('crawler_result/myswimpro_with_keywords.csv', escapechar='|')
myswimprodf2
# Out:
#                                                 review  rating  \
# 0    Got the app 5 weeks ago and I have made more p...       4
# 1    I am not a competíos swimmer but I enjoy it an...       5
# 2    Very impressed.  As a long time swimmer with a...       5
# 3    Let’s be honest, for many of us, our best comp...       5
# 4    First and foremost SwimPro is a great app with...       4
# ..                                                 ...     ...
# 499  Do not get this app!  It will work for a while...       1
# 500  I've used this app 3 times and all 3 times I g...       5
# 501  I downloaded the app to see if I could use it ...       1
# 502  App is useless. Cant even log in using email. ...       1
# 503  The worst,it is ten dollars a month just to un...       1
#
#                                                  title  \
# 0                                   My Swim Pro Review
# 1                                     Great investment
# 2                           From Analytics to Coaching
# 3    You can’t believe all that’s packed into this ...
# 4                              Great but not fail safe
# ..                                                 ...
# 499             Very Buggy and Incredibly Disapointing
# 500                                       Dissatisfied
# 501        DO NOT DOWNLOAD THE APP AND THEN CANCEL!!!!
# 502                                      Disappointing
# 503                                           Horrible
#
#                                    keywords_by_method1  \
# 0    [weeks ago, years of swimming, made more progr...
# 1    [competíos swimmer, wanted to push, based, wor...
# 2    [app, long time swimmer, impressed, Apple Watc...
# 3    [competitive swimming years, competitive swimm...
# 4    [dedicated swimmer, helpful and motivating, ap...
# ..                                                 ...
# 499  [Apple Watch, app, Watch, Apple, refuse to loa...
# 500  [inaccurate lap counts, times, inaccurate lap,...
# 501  [swimming for recreation, downloaded the app, ...
# 502  [App is useless, App, useless, log, password e...
# 503  [type of swim, unlock one stroke, worst,it is ...
#
#                                    keywords_by_method2
# 0    [swimming customized, app smartwatch, great ap...
# 1    [workout swimming, swim times, swimming tips, ...
# 2    [app workout, swim program, customizable worko...
# 3    [swim program, swim plans, swim community, swi...
# 4    [swimpro great, swimpro accurately, swimpro, t...
# ..                                                 ...
# 499  [apple watch, workouts apple, app work, app co...
# 500  [inaccurate lap, lap count, lap counts, swim l...
# 501  [trial subscription, subscription, subscriptio...
# 502  [app useless, app, service horrible, using ema...
# 503  [swim 000, 500 freestyle, just unlock, unlock,...
#
# [504 rows x 5 columns]

# %%
swimcomls = [swimcomdf2['review'][i] for i in range(len(swimcomdf2))]
swimcomdf2['keywords_by_method1'] = swimcomls
swimcomdf2['keywords_by_method2'] = swimcomls
for i in range(len(swimcomdf2)):
    # method 1
    kw_extractor = yake.KeywordExtractor(top=10, stopwords=None)
    keywords1 = kw_extractor.extract_keywords(text=swimcomls[i])
    keywords_list1 = []
    for kw, v in keywords1:
        keywords_list1.append(kw)
    swimcomdf2['keywords_by_method1'][i] = keywords_list1
    # method 2
    keywords2 = kw_model.extract_keywords(swimcomls[i], 
                                     keyphrase_ngram_range=(1, 2), 
                                     stop_words='english', 
                                     highlight=True,
                                     top_n=10)
    keywords_list2 = list(dict(keywords2).keys())
    swimcomdf2['keywords_by_method2'][i] = keywords_list2

# %%
swimcomdf2.to_csv('crawler_result/swimcom_with_keywords.csv', escapechar='|')
swimcomdf2
# Out:
#                                                 review  rating  \
# 0    After using this app for two years on a Pebble...       4
# 1    Strictly from an App Design standpoint, it bre...       3
# 2    They’ve made some good improvements to the app...       4
# 3    At 70 yo I sometimes ( no, all the time) need ...       5
# 4    This app has all the potential of being great ...       2
# ..                                                 ...     ...
# 226  I have used this app with my old Apple Watch S...       2
# 227  I want to use this app. I love swim.com and us...       2
# 228  ***Update - 02-10-2017\nMore updates have been...       2
# 229  App.has gone from functional to brick. Says it...       2
# 230  It's January now and I haven't been able to sy...       1
#
#                                               title  \
# 0    Improved tracking but data analysis still weak
# 1           It has potential, but still needs work.
# 2    Good, but a little wonky with stroke detection
# 3                             Use it for motivation
# 4                                  Inaccurate/buggy
# ..                                              ...
# 226                   Tracking still way off for me
# 227                      Inaccurate stroke accuracy
# 228                  Great Concept. Poor Execution.
# 229                                        Dead app
# 230                     Poor experience with Pebble
#
#                                    keywords_by_method1  \
# 0    [Pebble watch, hit or miss, Apple Watch, Pebbl...
# 1    [App Design standpoint, Design Recommendations...
# 2    [stroke detection, Apple Watch, ’ve made, sets...
# 3    [checking cumulative weekly, similar age group...
# 4    [distance swam makes, makes it annoying, total...
# ..                                                 ...
# 226  [Apple Watch Series, Watch Series, Apple Watch...
# 227  [default Apple application, Apple application,...
# 228  [app, workout, Apple Watch, watch, Update, sta...
# 229  [functional to brick, App.has, brick, connect ...
# 230  [kinds of gyrations, sync, Narcissistic Person...
#
#                                    keywords_by_method2
# 0    [swimmer apps, swims competitive, breaststroke...
# 1    [app functionality, app design, swims recorded...
# 2    [apple watch, watch stroke, improvements app, ...
# 3    [track daily, hobby app, keeping track, app be...
# 4    [app swimmers, swimmer 000meters, distance swa...
# ..                                                 ...
# 226  [swimming app, overestimate laps, issue swim, ...
# 227  [apple application, use app, app, app properly...
# 228  [workouts app, workout app, swimming app, work...
# 229  [app gone, connect server, server, app, gone f...
# 230  [pebble app, sync pebble, updated pebble, pebb...
#
# [231 rows x 5 columns]

# %%
formls = [formdf2['review'][i] for i in range(len(formdf2))]
formdf2['keywords_by_method1'] = formls
formdf2['keywords_by_method2'] = formls
for i in range(len(formdf2)):
    # method 1
    kw_extractor = yake.KeywordExtractor(top=10, stopwords=None)
    keywords1 = kw_extractor.extract_keywords(text=formls[i])
    keywords_list1 = []
    for kw, v in keywords1:
        keywords_list1.append(kw)
    formdf2['keywords_by_method1'][i] = keywords_list1
    # method 2
    keywords2 = kw_model.extract_keywords(formls[i], 
                                     keyphrase_ngram_range=(1, 2), 
                                     stop_words='english', 
                                     highlight=True,
                                     top_n=10)
    keywords_list2 = list(dict(keywords2).keys())
    formdf2['keywords_by_method2'][i] = keywords_list2

# %%
formdf2.to_csv('crawler_result/form_with_keywords.csv', escapechar='|')
formdf2
# Out:
#                                                review  rating  \
# 0   I like sport gadgets, but usually 9 out of 10 ...       5
# 1   My biggest question was if I was going to be a...       5
# 2   This has been a game changer in how I swim. Fi...       5
# 3   The googles are fine and the workout generatio...       3
# 4   This and bone conduction headphones have me sw...       5
# ..                                                ...     ...
# 56                              As described in title       1
# 57  It recognizes freestyle but all my breast stro...       1
# 58  I was excited when I first saw the Form goggle...       5
# 59  Great goggles, but major sync issues to Apple ...       2
# 60                          Great app, great goggles!       5
#
#                                                 title  \
# 0                          Amazing! Now even better 😃
# 1                                     Very motivating
# 2                                I love these goggles
# 3                    It’s fine, but not revolutionary
# 4             Made me fall back in love with swimming
# ..                                                ...
# 56  Unable to select goggle name in pairing setup....
# 57                            Bad at stroke detection
# 58                                Great Training Tech
# 59                      Does not sync to Apple Health
# 60                          Great app, great goggles!
#
#                                   keywords_by_method1  \
# 0   [Form swim goggles, sport gadgets, great disap...
# 1   [biggest question, started running Triathlon, ...
# 2   [game changer, Form goggles, goggles, app, rel...
# 3   [workout generation, googles are fine, generat...
# 4   [bone conduction headphones, bone conduction, ...
# ..                                                ...
# 56                                            [title]
# 57  [considered resting, swim spa, recognizes free...
# 58  [open water, open water functionality, open, w...
# 59  [Apple Health, FORM, Motion and Fitness, Apple...
# 60    [Great app, great goggles, Great, app, goggles]
#
#                                   keywords_by_method2
# 0   [swim goggles, apple watch, form goggle, compa...
# 1   [form goggles, goggles decided, goggles, data ...
# 2   [swim tracking, goggles app, swim app, type go...
# 3   [pausing workout, workout generation, workout ...
# 4   [workout planner, workout builder, swim pace, ...
# ..                                                ...
# 56                [described title, described, title]
# 57  [freestyle breast, resting swim, breast stroke...
# 58  [swim pace, form goggles, functionality goggle...
# 59  [apple health, health active, fitness form, he...
# 60  [great goggles, great app, goggles, app great,...
#
# [61 rows x 5 columns]

# %%
swimupls = [swimupdf2['review'][i] for i in range(len(swimupdf2))]
swimupdf2['keywords_by_method1'] = swimupls
swimupdf2['keywords_by_method2'] = swimupls
for i in range(len(swimupdf2)):
    # method 1
    kw_extractor = yake.KeywordExtractor(top=10, stopwords=None)
    keywords1 = kw_extractor.extract_keywords(text=swimupls[i])
    keywords_list1 = []
    for kw, v in keywords1:
        keywords_list1.append(kw)
    swimupdf2['keywords_by_method1'][i] = keywords_list1
    # method 2
    keywords2 = kw_model.extract_keywords(swimupls[i], 
                                     keyphrase_ngram_range=(1, 2), 
                                     stop_words='english', 
                                     highlight=True,
                                     top_n=10)
    keywords_list2 = list(dict(keywords2).keys())
    swimupdf2['keywords_by_method2'][i] = keywords_list2

# %%
swimupdf2.to_csv('crawler_result/swimup_with_keywords.csv', escapechar='|')
swimupdf2
# Out:
#                                               review  rating  \
# 0  Amazing app, amazing coach and superb courses....       5
# 1  Tried a few training apps for getting into swi...       5
# 2  I have been trying to learn how to freestyle w...       4
# 3  Great app! Simple as it is, works good for beg...       5
# 4  They put me on 2 levels before champion but th...       2
# 5              Thank you guys. Appreciate your work.       5
# 6  I love Swimup’s YouTube channel so I was reall...       3
# 7     No voice tutorials makes these videos useless.       1
#
#                                              title  \
# 0                                      Amazing app
# 1                                Best swimming app
# 2                                       Thank you!
# 3                                   Easy-peasy app
# 4  Honest oppinion of a 17 year old on a swim team
# 5                                       Great App.
# 6       I really want to like the app, I really do
# 7                                         No voice
#
#                                               string  \
# 0  [Amazing app, amazing coach, Amazing, app, swi...
# 1  Tried a few training apps for getting into swi...
# 2  I have been trying to learn how to freestyle w...
# 3  Great app! Simple as it is, works good for beg...
# 4  They put me on 2 levels before champion but th...
# 5              Thank you guys. Appreciate your work.
# 6  I love Swimup’s YouTube channel so I was reall...
# 7     No voice tutorials makes these videos useless.
#
#                                  keywords_by_method1  \
# 0  [Amazing app, amazing coach, Amazing, app, swi...
# 1  [training apps, Tips are helpful, easy to unde...
# 2  [coach, videos, learn, freestyle, helpful, SHO...
# 3  [Great app, Great, app, works good, Simple, wo...
# 4  [levels before champion, yards, hrs, levels, e...
# 5                                       [guys, work]
# 6  [love Swimup, Swimup ’s YouTube, Swimup, app, ...
# 7  [voice tutorials makes, videos useless, voice ...
#
#                                  keywords_by_method2
# 0  [enjoying app, subscription worth, swim course...
# 1  [training apps, getting swimming, swimming bes...
# 2  [freestyle coach, learn freestyle, freestyle, ...
# 3  [pool practice, pool, great app, app simple, b...
# 4  [champion workouts, swim hrs, training hrs, su...
# 5  [thank guys, appreciate work, guys appreciate,...
# 6  [swimup youtube, sound videos, swimup, love sw...
# 7  [voice tutorials, videos useless, tutorials, t...
