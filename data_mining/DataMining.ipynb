# %%
import pandas as pd

# %%
app_db = pd.read_excel('swimming app.xlsx')
app_db = app_db.transpose()
app_db.columns = app_db.iloc[0]
app_db = app_db.drop(app_db.index[0])
app_db
# Out:
# Unnamed: 0                              feebacks(comment(amoont of comment)/下載量)  \
# Duoswim:swim workout app                                                      no
# swim.com:swim tracker          顯示資訊完整，但同步紀錄沒辦法立即同步（4）\n/100+thousands in goog...
# swimup-swimming training                       no(1)/50+thousands in google play
# form swim                                      no(7)/10+thousands in google play
# myswimpro:#1 swim workout app                      沒有內建運動訓練好用，適合想照選手課表操練的試試看（23)
# garmin connect                                         整體使用上都很不錯記錄游泳功能很常出錯（4440）
# fitness                                                                無法同步(122)
#
# Unnamed: 0                            publish year  \
# Duoswim:swim workout app                   no data
# swim.com:swim tracker                 2015/january
# swimup-swimming training             2020/february
# form swim                      2019-08-02 00:00:00
# myswimpro:#1 swim workout app              no data
# ...

# %%
kw_db = app_db['functions']
kw_db = pd.DataFrame(kw_db)
kw_db.to_csv('kw_db.csv')

# %%
df_duoswim = pd.read_csv('crawler_result/duoswim.csv')
df_duoswim.drop(columns='Unnamed: 0', axis=1, inplace=True)
df_duoswim
# Out:
#                                                review  rating  \
# 0   Fantastic app, it changed my way to workout in...       5
# 1   Finally a swim app that looks great and provid...       5
# 2   Positive: The coaching side seems ok and decen...       2
# 3   This app is very easy to use. I love how you c...       5
# 4   Perfect app. Used to love swimming but hadn’t ...       5
# 5   After trying a few apps for my swimming, the D...       5
# 6   This is the first app I have found where I can...       5
# 7   Very nice app not so complicated as others. I ...       5
# 8   This app was exactly what I needed to start tr...       5
# 9   I currently swim 2-3 times a week and this app...       5
# 10  This app is quality, helping me build up my sw...       5
# 11  I am so impressed with the variety of programs...       5
# 12  I am an experienced swimmer and this app has s...       5
# 13  Perfect app for me to start my training journe...       5
# ...
